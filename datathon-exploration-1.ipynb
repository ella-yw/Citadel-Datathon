# %%
import os
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import numpy as np
import pandas as pd
import statsmodels.api as sm
import scipy
from scipy import stats
import matplotlib.pyplot as plt

# %%
# !ls "/content/drive/My Drive/Citadel-Datathon-2023/Data" #airports.csv and events_US.csv have error so use unicode escape
file_path = "/content/drive/My Drive/Citadel-Datathon-2023/Data/";
# Out:
# airlines.csv  events_US.csv  flight_traffic.csv  weather.csv
# airports.csv  fares.csv      stock_prices.csv

# %%
df_airlines = pd.read_csv(file_path + 'airlines.csv')
df_airports = pd.read_csv(file_path + 'airports.csv', encoding = 'unicode_escape')
df_events = pd.read_csv(file_path + 'events_US.csv', encoding = 'unicode_escape')
df_fares = pd.read_csv(file_path + 'fares.csv')
df_traffic = pd.read_csv(file_path + 'flight_traffic.csv')
df_stock = pd.read_csv(file_path + 'stock_prices.csv')
df_weather = pd.read_csv(file_path + 'weather.csv')

# %%
df_airlines.shape, df_airports.shape, df_events.shape, df_fares.shape, df_traffic.shape, df_stock.shape, df_weather.shape
# Out:
# ((61, 2),
#  (322, 6),
#  (1151, 4),
#  (80823, 255),
#  (5674621, 24),
#  (380, 10),
#  (353864, 12))

# %%
df_airlines.head(30)
# Out:
#    airline_id                                     airline_name
# 0          AA                           American Airlines Inc.
# 1          DL                             Delta Air Lines Inc.
# 2          UA                             United Airlines Inc.
# 3          WN                           Southwest Airlines Co.
# 4          HA                           Hawaiian Airlines Inc.
# 5          AS                             Alaska Airlines Inc.
# 6          9K                         Hyannis Air Service Inc.
# 7          BB                                Seaborne Airlines
# 8          KS                                           Penair
# 9          ZK                        Great Lakes Aviation Ltd.
# 10         VX                              Virgin America Inc.
# 11         3M                             Silver Airways Corp.
# 12         B6                      Jetblue Airways Corporation
# 13         MW                          Mokulele Flight Service
# ...

# %%
df_airports.head(10)
# Out:
#   airport_id                         airport_name           city state  \
# 0        ABE  Lehigh Valley International Airport      Allentown    PA
# 1        ABI             Abilene Regional Airport        Abilene    TX
# 2        ABQ    Albuquerque International Sunport    Albuquerque    NM
# 3        ABR            Aberdeen Regional Airport       Aberdeen    SD
# 4        ABY   Southwest Georgia Regional Airport         Albany    GA
# 5        ACK           Nantucket Memorial Airport      Nantucket    MA
# 6        ACT                Waco Regional Airport           Waco    TX
# 7        ACV                       Arcata Airport  Arcata/Eureka    CA
# 8        ACY  Atlantic City International Airport  Atlantic City    NJ
# 9        ADK                         Adak Airport           Adak    AK
#
#    latitude  longitude
# 0  40.65236  -75.44040
# 1  32.41132  -99.68190
# 2  35.04022 -106.60919
# 3  45.44906  -98.42183
# 4  31.53552  -84.19447
# 5  41.25305  -70.06018
# ...

# %%
df_events.head(10)
# Out:
#      date       city state                                         event_name
# 0  2/1/17  St. Louis    MO                                 NHL Winter Classic
# 1  4/1/17   New York    NY  National Board of Review of Motion Pictures Aw...
# 2  5/1/17   New York    NY                                Winter Jazzfest NYC
# 3  5/1/17  Las Vegas    NV      International Consumer Electronics Show (CES)
# 4  5/1/17   New York    NY                            Jazz Connect Conference
# 5  6/1/17   New York    NY                                Winter Jazzfest NYC
# 6  6/1/17  Las Vegas    NV      International Consumer Electronics Show (CES)
# 7  6/1/17   New York    NY                            Jazz Connect Conference
# 8  6/1/17   New York    NY                                    APAP conference
# 9  7/1/17   New York    NY                                Winter Jazzfest NYC

# %%
df_fares.shape
# Out:
# (80823, 255)

# %%
df_fares.head(10)
# Out:
#    quarter airline_id origin_airport destination_airport  distance    10  \
# 0        1         AA            CLT                 SGF       708     2
# 1        1         DL            DTW                 SAN      1956    13
# 2        1         DL            MSP                 ISN       546     7
# 3        1         AA            CLT                 RDU       130  2573
# 4        1         DL            ATL                 RIC       481   112
# 5        1         AA            CLT                 TPA       507   114
# 6        1         AA            DFW                 IND       761    23
# 7        1         UA            KOA                 LAX      2504    15
# 8        1         AA            DFW                 MHK       431    12
# 9        1         DL            LGA                 MCO       950     7
#
#      20   30   40   50  ...  2410  2420  2430  2440  2450  2460  2470  2480  \
# 0     6   11   15   32  ...     0     0     0     0     0     0     0     0
# ...

# %%
df_traffic.head(10)
# Out:
#    year  month  day airline_id origin_airport destination_airport  \
# 0  2017      1   17         AA            CLT                 PHX
# 1  2017      1   18         AA            CLT                 PHX
# 2  2017      1   19         AA            CLT                 PHX
# 3  2017      1   20         AA            CLT                 PHX
# 4  2017      1   21         AA            CLT                 PHX
# 5  2017      1   22         AA            CLT                 PHX
# 6  2017      1   23         AA            CLT                 PHX
# 7  2017      1   24         AA            CLT                 PHX
# 8  2017      1   25         AA            CLT                 PHX
# 9  2017      1   26         AA            CLT                 PHX
#
#    scheduled_departure  actual_departure  taxi_out  wheels_off  ...  \
# 0                 1619            1616.0      17.0      1633.0  ...
# 1                 1619            1614.0      13.0      1627.0  ...
# ...

# %%
list(df_traffic.columns)
# Out:
# ['year',
#  'month',
#  'day',
#  'airline_id',
#  'origin_airport',
#  'destination_airport',
#  'scheduled_departure',
#  'actual_departure',
#  'taxi_out',
#  'wheels_off',
#  'wheels_on',
#  'taxi_in',
#  'scheduled_arrival',
#  'actual_arrival',
#  'cancelled',
#  'diverted',
#  'scheduled_elapsed',
#  'actual_elapsed',
#  'distance',
#  'airline_delay',
#  'weather_delay',
#  'air_system_delay',
#  'security_delay',
#  'aircraft_delay']

# %%
#positive means earlier than expected
df_traffic['departure_diff'] = df_traffic['scheduled_departure'] - df_traffic['actual_departure']

# %%
#positive means earlier than expected
df_traffic['arrival_diff'] = df_traffic['scheduled_arrival'] - df_traffic['actual_arrival']

# %%
df_traffic[['departure_diff','arrival_diff']].head(10)
# Out:
#    departure_diff  arrival_diff
# 0             3.0          14.0
# 1             5.0          35.0
# 2             8.0          30.0
# 3           -37.0         -73.0
# 4           -13.0          -2.0
# 5           -17.0         -65.0
# 6             3.0         -51.0
# 7             0.0         -48.0
# 8             3.0         -50.0
# 9             1.0         -46.0

# %%
#taxi time
df_traffic['arrival_diff'].mean(), df_traffic['arrival_diff'].std()
# Out:
# (19.99180815131163, 288.18384863264777)

# %%
df_traffic['departure_diff'].mean(), df_traffic['departure_diff'].std()
# Out:
# (-4.309261387412539, 145.69217464486618)

# %%
df_stock.head(10)
# Out:
#   timestamp     AA       UA     B6     OO     AS       NK      WN     DL  \
# 0    4/6/18  51.12  69.6501  20.12  55.70  61.44  37.8576  55.865  53.67
# 1    4/5/18  52.14  70.6900  20.64  56.05  62.11  38.3000  56.860  54.21
# 2    4/4/18  52.04  69.9900  20.48  55.45  61.22  37.7000  56.360  53.86
# 3    4/3/18  51.47  69.1900  20.15  54.80  60.11  37.2200  55.970  53.72
# 4    4/2/18  49.78  66.7700  19.73  52.75  57.75  36.3500  54.340  51.95
# 5   3/29/18  51.96  69.4700  20.32  54.40  61.96  37.7800  57.280  54.81
# 6   3/28/18  50.85  67.9100  20.17  53.95  61.57  36.9900  56.250  53.93
# 7   3/27/18  50.90  68.1800  19.95  54.30  61.49  37.1900  56.690  54.26
# 8   3/26/18  51.86  68.4800  20.48  55.60  62.16  38.2700  57.590  55.06
# 9   3/23/18  51.01  67.3900  20.84  54.95  61.88  39.9600  56.720  53.90
#
#       HA
# 0  40.20
# 1  41.20
# 2  40.50
# 3  38.75
# 4  36.85
# 5  38.70
# 6  38.35
# 7  37.15
# 8  36.20
# 9  35.60

# %%
type(df_stock['timestamp'].iloc[0])
# Out:
# str

# %%
df_weather.head(10)
# Out:
#   airport_id                          airport_name  latitude  longitude  \
# 0        BUF  BUFFALO NIAGARA INTERNATIONAL, NY US   42.9408   -78.7358
# 1        BUF  BUFFALO NIAGARA INTERNATIONAL, NY US   42.9408   -78.7358
# 2        BUF  BUFFALO NIAGARA INTERNATIONAL, NY US   42.9408   -78.7358
# 3        BUF  BUFFALO NIAGARA INTERNATIONAL, NY US   42.9408   -78.7358
# 4        BUF  BUFFALO NIAGARA INTERNATIONAL, NY US   42.9408   -78.7358
# 5        BUF  BUFFALO NIAGARA INTERNATIONAL, NY US   42.9408   -78.7358
# 6        BUF  BUFFALO NIAGARA INTERNATIONAL, NY US   42.9408   -78.7358
# 7        BUF  BUFFALO NIAGARA INTERNATIONAL, NY US   42.9408   -78.7358
# 8        BUF  BUFFALO NIAGARA INTERNATIONAL, NY US   42.9408   -78.7358
# 9        BUF  BUFFALO NIAGARA INTERNATIONAL, NY US   42.9408   -78.7358
#
#    elevation             datetime  temperature  visibility  wind_direction  \
# 0      218.2  2017-01-01T00:54:00          3.9       16093             220
# ...

# %%
type(df_weather['datetime'].iloc[0])
# Out:
# str

# %%
df_weather['datetime'].iloc[0]
# Out:
# '2017-01-01T00:54:00'

# %%
df_weather_grouped = df_weather.groupby('airport_id',as_index=False).agg({'airport_name': lambda x: list(x), 'datetime': lambda x: list(x)})

# %%
df_weather_grouped.shape
# Out:
# (242, 3)

# %%
df_weather_grouped.head(10)
# Out:
#   airport_id                                       airport_name  \
# 0        ABE  [ALLENTOWN LEHIGH VALLEY INTERNATIONAL AIRPORT...
# 1        ABI  [ABILENE REGIONAL AIRPORT, TX US, ABILENE REGI...
# 2        ABQ  [ALBUQUERQUE INTERNATIONAL AIRPORT, NM US, ALB...
# 3        ABR  [ABERDEEN REGIONAL AIRPORT, SD US, ABERDEEN RE...
# 4        ABY  [ALBANY SW GEORGIA REGIONAL AIRPORT, GA US, AL...
# 5        ACK  [NANTUCKET MEMORIAL AIRPORT, MA US, NANTUCKET ...
# 6        ACT  [WACO REGIONAL AIRPORT, TX US, WACO REGIONAL A...
# 7        ACV  [ARCATA EUREKA AIRPORT, CA US, ARCATA EUREKA A...
# 8        ACY  [ATLANTIC CITY INTERNATIONAL AIRPORT, NJ US, A...
# 9        ADK  [ADAK AIRPORT, AK US, ADAK AIRPORT, AK US, ADA...
#
#                                             datetime
# 0  [2017-01-01T00:51:00, 2017-01-01T06:51:00, 201...
# 1  [2017-01-01T00:52:00, 2017-01-01T06:52:00, 201...
# 2  [2017-01-01T00:52:00, 2017-01-01T06:52:00, 201...
# ...
